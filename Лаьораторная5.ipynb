# %% [markdown]
# <a href="https://colab.research.google.com/github/shvlade/Pythonlab5/blob/master/%D0%9B%D0%B0%D1%8C%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y, label = 'sin(x)',color = 'red')
plt.plot(x, z, label = 'cos(x)', color = 'yellow')
plt.title('Regular graphics')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.random.normal(0, 1, 1000)
plt.hist(x, bins = 20, color='purple')
plt.title('Гистограмма')
plt.xlabel('Знач')
plt.ylabel('Частота')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
x = np.random.randint(1, 11, size = (5,5))
print(x)
print(np.mean(x))
print(np.max(x))
print(np.min(x))
print(np.sum(x))
# Out:
# [[ 8  6  6  2 10]
#  [ 2  5  2 10 10]
#  [ 1  9  5  3 10]
#  [ 4  1  6  1  3]
#  [ 5  9  1  6  2]]
# 5.08
# 10
# 1
# 127

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(1, 11, size = (5,5))
plt.imshow(x, cmap = 'plasma')
plt.colorbar()
plt.show()
print(x)
# Out:
# [[7 8 9 6 5]
#  [2 1 2 3 8]
#  [6 1 2 5 3]
#  [4 7 5 4 7]
#  [5 8 6 5 3]]

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

hok, (graf1,graf2,graf3) = plt.subplots(3, 1, figsize=(8,10))

x = np.linspace(0,10,50)
y = (x**2)
graf1.plot(x, y,'g-', linewidth=3)
graf1.set_title('Линейный график y**2')
graf1.set_xlabel('X')
graf1.set_ylabel('Y')

x_r = np.random.rand(30) * 10
y_r = np.random.rand(30) * 1000
graf2.scatter(x_r,y_r, c='r', alpha=0.5)
graf2.set_title('Точечный график случайных точек')
graf2.set_xlabel('X координата')
graf2.set_ylabel('Y координата')

cat = ['A','B','C']
val = [3,7,2]
graf3.bar(cat,val,color = ['yellow','red','orange'])
graf3.set_title('Столбчатая диаграмма для категориальных данных')
graf3.set_xlabel('Категории')
graf3.set_ylabel('Значения')
plt.tight_layout(pad=2.0)
plt.show()
